# %% [markdown]
# <a href="https://colab.research.google.com/github/hemoabdullah/PCVK_smst5/blob/main/Week2_Hammam_Abdullah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Pics/cute.jpg')
plt.imshow(img)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Pics/cute.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/Pics/cute.jpg')

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros((512,512,3), dtype=np.int16)
plt.imshow(black_img)
black_img2 = black_img.copy()

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 158), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# **TASK**

# %% [markdown]
# 1. By using figsize, notice whether the image pixel size also changes?

# %%
plt.figure(figsize=(5,5))   # smaller figure
plt.imshow(img)
plt.title("Small Figure Size")
plt.show()

plt.figure(figsize=(10,8))  # larger figure
plt.imshow(img)
plt.title("Large Figure Size")
plt.show()

# %% [markdown]
# 2.	Show images in Red-Green and Green-Blue channels only!

# %%
b, g, r = cv.split(img)

# Red-Green only (Blue = 0)
rg = cv.merge([np.zeros_like(b), g, r])

# Green-Blue only (Red = 0)
gb = cv.merge([b, g, np.zeros_like(r)])

plt.subplot(1,2,1); plt.imshow(cv.cvtColor(rg, cv.COLOR_BGR2RGB)); plt.title("Red-Green")
plt.subplot(1,2,2); plt.imshow(cv.cvtColor(gb, cv.COLOR_BGR2RGB)); plt.title("Green-Blue")
plt.show()

# %% [markdown]
# 3.	Show image row 10-100, column 10-100!

# %%
cropped_img = img[10:100, 10:100]
plt.imshow(cv.cvtColor(cropped_img, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 4.	Show image rows 5-30, all columns, channel Green only!

# %%
green_img = img[5:30, :, 1] #take green channel, rows 5-30, all columns
plt.imshow(green_img, cmap='gray')
plt.show()

# %% [markdown]
# 5.	Create 5 boxes of different sizes and colors in one image. it is recommended to use random numbers!

# %%
canvas = np.zeros((512,512,3), dtype=np.uint8)

for i in range(5):
    pt1 = (np.random.randint(0,400), np.random.randint(0,400))
    pt2 = (pt1[0]+np.random.randint(20,100), pt1[1]+np.random.randint(20,100))
    color = (np.random.randint(0, 256), np.random.randint(0, 256), np.random.randint(0, 256))
    cv.rectangle(canvas, pt1, pt2, color, -1)

plt.imshow(cv.cvtColor(canvas, cv.COLOR_BGR2RGB))
plt.title("Random 5 Boxes")
plt.show()

# %% [markdown]
# 6.	Show the image upside down!

# %%
flipped = cv.flip(canvas, 0)   # 0 = vertical flip
plt.imshow(cv.cvtColor(flipped, cv.COLOR_BGR2RGB))
plt.title("Upside Down")
plt.show()

# %% [markdown]
# 7.	Make rectangles and circles on the face of your photo image when you are active (not a passport photo).

# %%
photo = cv.imread('/content/drive/MyDrive/PCVK/Pics/TASK.jpg')

# Rectangle that matches the circle’s bounding box
cv.rectangle(photo, pt1=(35,40), pt2=(155,160), color=(0,255,0), thickness=3)

# Circle already perfect
cv.circle(photo, center=(95,100), radius=60, color=(255,0,0), thickness=3)

plt.imshow(cv.cvtColor(photo, cv.COLOR_BGR2RGB))
plt.title("Rectangle & Circle aligned on Face")
plt.show()

# %% [markdown]
# 8.	Create a rectangle in the lower left corner of channel B in the RGB color space from the kitten / lena / mandrill / male / female / couple / sailboat / peppers image !

# %%
b,g,r = cv.split(img)
b[700:835, 0:135] = 255   # white rectangle in lower-left corner of B channel

plt.imshow(b, cmap='gray')
plt.title("Rectangle in Blue Channel")
plt.show()

# %% [markdown]
# 9.	Complete the writing of the file name on the image file from question no.8. use the font, font size, and font color according to your wishes.

# %%
font = cv.FONT_HERSHEY_TRIPLEX
cv.putText(img, text='kitten.jpg', org=(800,700), fontFace=font, fontScale=2, color=(255,255,255), thickness=2, lineType=cv.LINE_AA)
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title("my cat")
plt.show()

# %% [markdown]
# Group 6 close employment and citizenship

# %%
ktp = cv.imread('/content/drive/MyDrive/PCVK/Pics/KTP.jpg')
cv.rectangle(ktp, pt1=(160,265), pt2=(290,283), color=(195,40,135), thickness=-1)  # employment
cv.rectangle(ktp, pt1=(160,285), pt2=(195,300), color=(85,145,29), thickness=-1)  # citizenship

plt.imshow(cv.cvtColor(ktp, cv.COLOR_BGR2RGB))
plt.show()
